# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("population_by_age_group.csv")
df
# Out:
#                Country     Total      65+  25-64 years  15-24 years  \
# 0          Afghanistan  40099460   964016     12995277      8727160
# 1              Albania   2854710   463442      1527360       399113
# 2              Algeria  44177964  2731079     21871300      6007614
# 3       American Samoa     45056     3088        22433         7141
# 4              Andorra     79057    11499        48651         8570
# ..                 ...       ...      ...          ...          ...
# 230  Wallis and Futuna     11654     1521         5767         1652
# 231     Western Sahara    565590    31718       314200        80572
# 232              Yemen  32981644   886890     12210659      6733620
# 233             Zambia  19473132   338628      6734346      3975624
# 234           Zimbabwe  15993525   537915      5572892      3342436
#
#      5-14 years  0-4 years
# 0      10922454    6490554
# 1        323402     141393
# 2       8697129    4870841
# 3          8365       4029
# ...

# %%
df.shape
# Out:
# (235, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Country      235 non-null    object
#  1   Total        235 non-null    int64
#  2   65+          235 non-null    int64
#  3   25-64 years  235 non-null    int64
#  4   15-24 years  235 non-null    int64
#  5   5-14 years   235 non-null    int64
#  6   0-4 years    235 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 12.0+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("population_by_age_group.csv")

# Filter data for India
df_india = df[df['Country'] == 'India']

# Select only age groups and the total population column
age_categories = ['0-4 years', '5-14 years', '15-24 years', '25-64 years', '65+']
total_population = df_india['Total'].values[0]

# Create a bar chart for age distribution
plt.figure(figsize=(10, 6))
plt.bar(age_categories, df_india[age_categories].iloc[0], color='skyblue', edgecolor='black')
plt.xlabel('Age Category', fontsize=12)
plt.ylabel('Population Count (in millions)', fontsize=12, fontname='Consolas')
plt.title('Bar Chart for Age Distribution in India (2021)', fontsize=14, fontname='Consolas')
plt.xticks(rotation=0, fontname='Consolas')

# Convert total population to millions
total_population_million = total_population / 10**6

# Display y-axis ticks in millions since dataset is big
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
plt.yticks(fontname='Consolas')

# Show plot
plt.show()
